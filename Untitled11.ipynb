# %%
import numpy as np
phi = (1 + np.sqrt(5))/2
print(f"Golden ratio: {phi}")
print(f"Your fine structure formula: α ≈ 1/{101*(phi**(np.pi-2) - np.sqrt(3)):.6f}")
# Out:
# Golden ratio: 1.618033988749895
# Your fine structure formula: α ≈ 1/0.007302
