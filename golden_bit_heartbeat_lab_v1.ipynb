# %% [markdown]
# ## Provenance hashes

# %%
hashes = {f: hashlib.md5(open(os.path.join(FIG_DIR, f), 'rb').read()).hexdigest()
          for f in os.listdir(FIG_DIR)}
print(json.dumps(hashes, indent=2))
# Out:
# {
#   "decay.png": "789622389496a07233c4eef3c94e1b95"
# }
