# %%
# 🔍 Explore φⁿ·s damping: Vary s from 0.5 to 2.0 and observe effect on convergence

s_values = [0.5, 0.75, 1.0, 1.25, 1.5, 2.0]
N_vals = list(range(1, 41))

# Store convergence curves for different s
curves = {}
for s in s_values:
    curves[s] = symbolic_zeta_phi_prime_safe(40, s=s)

# Plotting
plt.figure(figsize=(10, 6))
for s in s_values:
    plt.plot(N_vals, curves[s], label=f"s = {s}", marker='o')
plt.title("Effect of Scaling Damping Exponent (s) on ∑ 1/pₙ^{φⁿ·s}")
plt.xlabel("N (Number of Terms)")
plt.ylabel("Cumulative Sum")
plt.grid(True)
plt.legend(title="Scaling Parameter s")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1091357638.py in <cell line: 0>()
#       7 curves = {}
#       8 for s in s_values:
# ----> 9     curves[s] = symbolic_zeta_phi_prime_safe(40, s=s)
#      10
#      11 # Plotting
#
# NameError: name 'symbolic_zeta_phi_prime_safe' is not defined
