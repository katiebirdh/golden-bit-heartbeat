# %%
# Paste / edit your raw rows below ▼
raw_rows = [

    #  bits   k      φ_micro      λ    rel_err
    (64,  3.6, 0.003942, 0.0, 0.4117525875906678269),
    (64,  3.8, 0.003942, 0.0, 0.4117525875906678269),
    (64,  4.0, 0.003942, 0.0, 0.4117525875906678269),
    (64,  4.2, 0.003942, 0.0, 0.4117525875906678269),
    (128, 3.6, 0.003942, 0.0, 0.4117525875906678271),
    (128, 3.8, 0.003942, 0.0, 0.4117525875906678271),
    (128, 4.0, 0.003942, 0.0, 0.4117525875906678271),
    (128, 4.2, 0.003942, 0.0, 0.4117525875906678271),

]

import math, numpy as np, pandas as pd
df = pd.DataFrame(raw_rows, columns=['bits','k','phi','lam','rel_err'])
print("Preview→"); display(df.head())
# Out:
# Preview→
#    bits    k       phi  lam   rel_err
# 0    64  3.6  0.003942  0.0  0.411753
# 1    64  3.8  0.003942  0.0  0.411753
# 2    64  4.0  0.003942  0.0  0.411753
# 3    64  4.2  0.003942  0.0  0.411753
# 4   128  3.6  0.003942  0.0  0.411753

# %%
# ➌ --- TAG PLATEAUX & EXHAUSTIVE RUN --------------------------------------
import itertools, json, os

def tag_plateaus(frame: pd.DataFrame, eps: float):
    base = frame['rel_err'].min()
    out  = frame.copy()
    out['plateau'] = ((out['rel_err']-base)/eps).astype(int)
    return out

views=[]
for eps in [1e-4,5e-6,1e-7]:
    tagged = tag_plateaus(df, eps)
    for op_name, op_fn in OPS.items():
        tmp = tagged.copy()
        tmp['ε']  = eps
        tmp['op'] = op_name
        tmp['rel_err'] = tmp['rel_err'].apply(op_fn)   # element‑wise
        views.append(tmp.iloc[:60])   # keep first 60 rows per slice for eyeball

result = pd.concat(views, ignore_index=True)

# save
raw_file = 'plateaus_raw_v14.xlsx'
ops_file = 'plateaus_ops_v14.xlsx'
df.to_excel(raw_file, index=False)
result.to_excel(ops_file, index=False)
print(f"Files written: {raw_file} and {ops_file}")
display(result.head(30))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-17-422668193.py in <cell line: 0>()
#      15         tmp['ε']  = eps
#      16         tmp['op'] = op_name
# ---> 17         tmp['rel_err'] = tmp['rel_err'].apply(op_fn)   # element‑wise
#      18         views.append(tmp.iloc[:60])   # keep first 60 rows per slice for eyeball
#      19
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipython-input-16-1899236962.py in <lambda>(x)
#      34
#      35 # discovered route (n‑α/β)/10
# ---> 36 add('αβ10', lambda x: (x*αbeta-10)/10)  # placeholder if needed
#      37
#      38 # power‑towers short ↑↑2  (guard against blow‑ups)
#
# NameError: name 'αbeta' is not defined
